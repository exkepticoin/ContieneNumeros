# %% [markdown]
# <a href="https://colab.research.google.com/github/exkepticoin/ContieneNumeros/blob/main/imaGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate diffusers
from transformers import pipeline

# Para mostrar las imágenes directamente en el notebook
import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 35.3 MB/s eta 0:00:00
# ...

# %%
# !pip install torch torchvision torchaudio

# %%
import torch

# %%
from diffusers import StableDiffusionPipeline

# Cargar un modelo alternativo
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# (…)kpoints/scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# ...

# %%
# Generar una imagen
prompt = "Half-length photo of Jesus Christ looking straight into the camera. Hyper realistic, detailed, professional camera."
image = pipe(prompt).images[0]
image.save("Coloring.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
